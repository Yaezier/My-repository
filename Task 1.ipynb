# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv('train.csv') # 使用相对路径导入数据。相对路径：和py文件处在同一目录下的文件路径

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 使用绝对路径载入数据。绝对路径：从盘符开始到达文件的的路径。
path = os.path.abspath('train.csv')
print(path)
# Out:
# C:\Users\Li\Desktop\动手学数据分析\train.csv

# %%
df = pd.read_csv(path)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
tb = pd.read_table(path)
tb.head(10)
# Out:
#   PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0  1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...
# 1  2,1,1,"Cumings, Mrs. John Bradley (Florence Br...
# 2  3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,S...
# 3  4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May ...
# 4  5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...
# 5  6,0,3,"Moran, Mr. James",male,,0,0,330877,8.45...
# 6  7,0,1,"McCarthy, Mr. Timothy J",male,54,0,0,17...
# 7  8,0,3,"Palsson, Master. Gosta Leonard",male,2,...
# 8  9,1,3,"Johnson, Mrs. Oscar W (Elisabeth Vilhel...
# 9  10,1,2,"Nasser, Mrs. Nicholas (Adele Achem)",f...

# %%
## table和dataframe看上去是分割不同，宽度都不一样，百度后发现分隔符不同，前者制表符后者逗号，那么试一下
tb = pd.read_table('train.csv', sep = ',')
tb.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# nice

# %%
# tsv = Tab-separated values
# csv = Comma-separated values
# 读取tsv和csv文件都用pd.read_csv,分隔符改一下而已，保存文件用to_csv,试一下
data = pd.read_csv('train.csv', sep = '\t')
data.to_csv('train.tsv')

# %%
# tsv 在记事本打开 csv 在excel打开

# %%
data = pd.read_csv('train.tsv', sep = ',')
data.to_csv('train02.csv', index = False)

# %%
df = pd.read_csv('train02.csv') # 打开train02会发现数据集中在第一格，然后多了一列检索,read没有检索，只能在to里面删除
df.head()
# 但是还是会多一列，咋办.直接去文件删除吧
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#   PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0  1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...
# 1  2,1,1,"Cumings, Mrs. John Bradley (Florence Br...
# 2  3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,S...
# 3  4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May ...
# 4  5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...

# %%
# df = pd.read_csv('train02.csv', index = False) # 打开train02会发现数据集中在第一格，然后多了一列检索
# df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 df = pd.read_csv('train02.csv', index = False) # 打开train02会发现数据集中在第一格，然后多了一列检索
#       2 df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
df = pd.read_csv('train02.csv', index_col= False)
df.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#   PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0  1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...
# 1  2,1,1,"Cumings, Mrs. John Bradley (Florence Br...
# 2  3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,S...
# 3  4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May ...
# 4  5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 思考 什么是逐块读取？为什么要逐块读取呢？

#【提示】大家可以chunker(数据块)是什么类型？用for循环打印出来出处具体的样子是什么？

# %%
# 把数据分成一小块一小块的chunker，试一下

# %%
chunker = pd.read_csv('train.csv', chunksize = 1000)
print(type(chunker))
# 返回的对象是TextFileReader
# Out:
# <class 'pandas.io.parsers.readers.TextFileReader'>

# %%
print(chunker)

# %%
chunker.get_chunk()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 chunker.get_chunk()
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1284, in TextFileReader.get_chunk(self, size)
#    1282         raise StopIteration
#    1283     size = min(size, self.nrows - self._currow)
# -> 1284 return self.read(nrows=size)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
# ...

# %%
for i in chunker:
    print(i)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv('train.csv',names=['乘客ID', '是否幸存', '乘客等级(1/2/3等舱位)', '乘客姓名', '性别', '年龄', '堂兄弟/妹个数', '父母与小孩个数', '船票信息', '票价', '客舱', '登船港口'], header=0)
df.head()
# Out:
#    乘客ID  是否幸存  乘客等级(1/2/3等舱位)  \
# 0     1     0               3
# 1     2     1               1
# 2     3     1               3
# 3     4     1               1
# 4     5     0               3
#
#                                                 乘客姓名      性别    年龄  堂兄弟/妹个数  \
# 0                            Braund, Mr. Owen Harris    male  22.0        1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0        1
# 2                             Heikkinen, Miss. Laina  female  26.0        0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0        1
# 4                           Allen, Mr. William Henry    male  35.0        0
#
#    父母与小孩个数              船票信息       票价    客舱 登船港口
# 0        0         A/5 21171   7.2500   NaN    S
# 1        0          PC 17599  71.2833   C85    C
# 2        0  STON/O2. 3101282   7.9250   NaN    S
# 3        0            113803  53.1000  C123    S
# 4        0            373450   8.0500   NaN    S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.notnull()
# 加括号和不加括号返回不一样，一个是dataframe一个是table
# Out:
#      乘客ID  是否幸存  乘客等级(1/2/3等舱位)  乘客姓名    性别     年龄  堂兄弟/妹个数  父母与小孩个数  船票信息  \
# 0    True  True            True  True  True   True     True     True  True
# 1    True  True            True  True  True   True     True     True  True
# 2    True  True            True  True  True   True     True     True  True
# 3    True  True            True  True  True   True     True     True  True
# 4    True  True            True  True  True   True     True     True  True
# ..    ...   ...             ...   ...   ...    ...      ...      ...   ...
# 886  True  True            True  True  True   True     True     True  True
# 887  True  True            True  True  True   True     True     True  True
# 888  True  True            True  True  True  False     True     True  True
# 889  True  True            True  True  True   True     True     True  True
# 890  True  True            True  True  True   True     True     True  True
#
#        票价     客舱  登船港口
# 0    True  False  True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   乘客ID            891 non-null    int64
#  1   是否幸存            891 non-null    int64
#  2   乘客等级(1/2/3等舱位)  891 non-null    int64
#  3   乘客姓名            891 non-null    object
#  4   性别              891 non-null    object
#  5   年龄              714 non-null    float64
#  6   堂兄弟/妹个数         891 non-null    int64
#  7   父母与小孩个数         891 non-null    int64
#  8   船票信息            891 non-null    object
#  9   票价              891 non-null    float64
#  10  客舱              204 non-null    object
#  11  登船港口            889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head(10)
# Out:
#    乘客ID  是否幸存  乘客等级(1/2/3等舱位)  \
# 0     1     0               3
# 1     2     1               1
# 2     3     1               3
# 3     4     1               1
# 4     5     0               3
# 5     6     0               3
# 6     7     0               1
# 7     8     0               3
# 8     9     1               3
# 9    10     1               2
#
#                                                 乘客姓名      性别    年龄  堂兄弟/妹个数  \
# 0                            Braund, Mr. Owen Harris    male  22.0        1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0        1
# 2                             Heikkinen, Miss. Laina  female  26.0        0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0        1
# 4                           Allen, Mr. William Henry    male  35.0        0
# 5                                   Moran, Mr. James    male   NaN        0
# 6                            McCarthy, Mr. Timothy J    male  54.0        0
# ...

# %%
df.tail(15)
# Out:
#      乘客ID  是否幸存  乘客等级(1/2/3等舱位)  \
# 876   877     0               3
# 877   878     0               3
# 878   879     0               3
# 879   880     1               1
# 880   881     1               2
# 881   882     0               3
# 882   883     0               3
# 883   884     0               2
# 884   885     0               3
# 885   886     0               3
# 886   887     0               2
# 887   888     1               1
# 888   889     0               3
# 889   890     1               1
# 890   891     0               3
#
#                                               乘客姓名      性别    年龄  堂兄弟/妹个数  \
# 876                  Gustafsson, Mr. Alfred Ossian    male  20.0        0
# 877                           Petroff, Mr. Nedelio    male  19.0        0
# 878                             Laleff, Mr. Kristo    male   NaN        0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0        0
# ...

# %%
df.isnull()
# Out:
#       乘客ID   是否幸存  乘客等级(1/2/3等舱位)   乘客姓名     性别     年龄  堂兄弟/妹个数  父母与小孩个数  \
# 0    False  False           False  False  False  False    False    False
# 1    False  False           False  False  False  False    False    False
# 2    False  False           False  False  False  False    False    False
# 3    False  False           False  False  False  False    False    False
# 4    False  False           False  False  False  False    False    False
# ..     ...    ...             ...    ...    ...    ...      ...      ...
# 886  False  False           False  False  False  False    False    False
# 887  False  False           False  False  False  False    False    False
# 888  False  False           False  False  False   True    False    False
# 889  False  False           False  False  False  False    False    False
# 890  False  False           False  False  False  False    False    False
#
#       船票信息     票价     客舱   登船港口
# 0    False  False   True  False
# ...

# %%
df.to_csv('train_chinese.csv', encoding='GBK')

# %%
df.to_csv('train_chinese2.csv', encoding='utf-8')
# GBK正常utf-8乱码
# gbk比utf8兼容更多的汉字，utf8并不是所有汉字都能显示，而gbk就几乎都可以
